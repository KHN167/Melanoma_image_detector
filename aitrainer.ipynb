# %%
import os
import tensorflow as tf
import cv2
import imghdr

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
data_dir = 'data'
data_ext = ['jpeg', 'jpg', 'png', 'bmp']
os.listdir(os.path.join(data_dir,'benign'))
# Out:
# ['melanoma_0.jpg',
#  'melanoma_1.jpg',
#  'melanoma_10.jpg',
#  'melanoma_100.jpg',
#  'melanoma_1000.jpg',
#  'melanoma_1001.jpg',
#  'melanoma_1002.jpg',
#  'melanoma_1003.jpg',
#  'melanoma_1004.jpg',
#  'melanoma_1005.jpg',
#  'melanoma_1006.jpg',
#  'melanoma_1007.jpg',
#  'melanoma_1008.jpg',
#  'melanoma_1009.jpg',
#  'melanoma_101.jpg',
#  'melanoma_1010.jpg',
#  'melanoma_1011.jpg',
#  'melanoma_1012.jpg',
#  'melanoma_1013.jpg',
#  'melanoma_1014.jpg',
#  'melanoma_1015.jpg',
#  'melanoma_1016.jpg',
#  'melanoma_1017.jpg',
#  'melanoma_1018.jpg',
#  'melanoma_1019.jpg',
#  'melanoma_102.jpg',
#  'melanoma_1020.jpg',
#  'melanoma_1021.jpg',
#  'melanoma_1022.jpg',
#  'melanoma_1023.jpg',
#  'melanoma_1024.jpg',
#  'melanoma_1025.jpg',
#  'melanoma_1026.jpg',
#  'melanoma_1027.jpg',
#  'melanoma_1028.jpg',
#  'melanoma_1029.jpg',
#  'melanoma_103.jpg',
#  'melanoma_1030.jpg',
#  'melanoma_1031.jpg',
#  'melanoma_1032.jpg',
#  'melanoma_1033.jpg',
#  'melanoma_1034.jpg',
# ...
